# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import monai
from PIL import Image
from fetch.viz import m3d, show
import glob
import monai.transforms as MT
from preproc import *

# %%
show(img.moveaxis(0,0)[sag_ndx], mask.moveaxis(0,0)[sag_ndx])
show(img.moveaxis(1,0)[cor_ndx], mask.moveaxis(1,0)[cor_ndx])
show(img.moveaxis(2,0)[ax_ndx], mask.moveaxis(2,0)[ax_ndx])
# Out:
# <Axes: >
